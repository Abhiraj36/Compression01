# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhiraj36/Compression01/blob/main/compression_original_STL-10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from torchvision.utils import save_image
import os
# !pip install scikit-image wandb

from skimage.metrics import structural_similarity as ssim
import numpy as np
import time


import wandb
wandb.init(
    project="skip-autoencoder-compression",
    config={
        "epochs_ae": 5,
        "epochs_comp": 10,
        "batch_size": 64,      # Lowered for bigger images
        "lr": 0.001,
        "dataset": "STL10"     # <-- updated
    }
)
config = wandb.config


# Ensure output directory exists
os.makedirs("output_images", exist_ok=True)

# Device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Skip-Connected Autoencoder
class SkipAutoencoder(nn.Module):
    def __init__(self):
        super(SkipAutoencoder, self).__init__()
        # Encoder
        self.enc1 = nn.Sequential(
            nn.Conv2d(3, 64, 3, padding=1), nn.ReLU(inplace=True))
        self.enc2 = nn.Sequential(
            nn.Conv2d(64, 128, 3, stride=2, padding=1), nn.ReLU(inplace=True))  # 48x48
        self.enc3 = nn.Sequential(
            nn.Conv2d(128, 256, 3, stride=2, padding=1), nn.ReLU(inplace=True))  # 24x24

        # Decoder
        self.dec1 = nn.Sequential(
            nn.ConvTranspose2d(256, 128, 4, stride=2, padding=1), nn.ReLU(inplace=True))  # 48x48
        self.dec2 = nn.Sequential(
            nn.ConvTranspose2d(256, 64, 4, stride=2, padding=1), nn.ReLU(inplace=True))  # 96x96
        self.dec3 = nn.Sequential(
            nn.Conv2d(128, 3, 3, padding=1), nn.Tanh())

    def forward(self, x):
        e1 = self.enc1(x)  # [B, 64, 96, 96]
        e2 = self.enc2(e1) # [B, 128, 48, 48]
        e3 = self.enc3(e2) # [B, 256, 24, 24]

        d1 = self.dec1(e3)                # [B, 128, 48, 48]
        d1_cat = torch.cat([d1, e2], 1)   # [B, 256, 48, 48]

        d2 = self.dec2(d1_cat)            # [B, 64, 96, 96]
        d2_cat = torch.cat([d2, e1], 1)   # [B, 128, 96, 96]

        out = self.dec3(d2_cat)           # [B, 3, 96, 96]

        return out, e3  # output and latent



# Latent Compressor
class LatentCompressor(nn.Module):
    def __init__(self, input_channels=256):
        super(LatentCompressor, self).__init__()
        self.encoder = nn.Sequential(
            nn.Conv2d(input_channels, 128, kernel_size=3, stride=2, padding=1),  # 24x24 → 12x12
            nn.ReLU(),
            nn.Conv2d(128, 64, kernel_size=3, stride=2, padding=1),              # 12x12 → 6x6
            nn.ReLU(),
        )
        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(64, 128, kernel_size=4, stride=2, padding=1),     # 6x6 → 12x12
            nn.ReLU(),
            nn.ConvTranspose2d(128, 256, kernel_size=4, stride=2, padding=1),    # 12x12 → 24x24
            nn.ReLU(),
        )

        # Final projection to match the latent shape exactly (in case of residual mismatch)
        self.project = nn.Conv2d(256, input_channels, kernel_size=1)

    def forward(self, x):
        z = self.encoder(x)
        out = self.decoder(z)
        projected = self.project(out)
        return projected


# Data Preparation  (UPDATED FOR STL-10)
transform = transforms.Compose([
    transforms.Resize(96),  # STL10 images are 96x96
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))  # normalize to [-1,1]
])

trainset = datasets.STL10(root='./data', split='train', download=True, transform=transform)
testset = datasets.STL10(root='./data', split='test', download=True, transform=transform)

trainloader = DataLoader(trainset, batch_size=config.batch_size, shuffle=True)
testloader = DataLoader(testset, batch_size=16, shuffle=False)


# Initialize Models
autoencoder = SkipAutoencoder().to(device)
latent_compressor = LatentCompressor().to(device)


# Train Autoencoder First (optional: or load pretrained)
ae_optimizer = optim.Adam(autoencoder.parameters(), lr=config.lr)
ae_criterion = nn.MSELoss()

print("\nTraining Autoencoder...")
autoencoder.train()
for epoch in range(config.epochs_ae):
    total_loss = 0.0
    for imgs, _ in trainloader:
        imgs = imgs.to(device)
        ae_optimizer.zero_grad()
        recon, _ = autoencoder(imgs)
        loss = ae_criterion(recon, imgs)
        loss.backward()
        ae_optimizer.step()
        total_loss += loss.item() * imgs.size(0)

    avg_loss = total_loss / len(trainloader.dataset)
    print(f"Autoencoder Epoch [{epoch+1}/{config.epochs_ae}], Loss: {avg_loss:.6f}")

    #  Log to wandb
    wandb.log({
        "train/ae_loss": avg_loss,
        "epoch": epoch + 1,
        "train/recon_sample": [wandb.Image(recon[0].cpu(), caption="Reconstructed"),
                               wandb.Image(imgs[0].cpu(), caption="Original")]
    })
# Out:
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (0.25.2)
# Requirement already satisfied: wandb in /usr/local/lib/python3.11/dist-packages (0.21.0)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (2.0.2)
# Requirement already satisfied: scipy>=1.11.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (1.16.1)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (3.5)
# Requirement already satisfied: pillow>=10.1 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (11.3.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (2025.6.11)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (0.4)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.11/dist-packages (from wandb) (8.2.1)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (3.1.45)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from wandb) (4.3.8)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (5.29.5)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.11.7)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from wandb) (6.0.2)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.32.3)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.34.0)
# Requirement already satisfied: typing-extensions<5,>=4.8 in /usr/local/lib/python3.11/dist-packages (from wandb) (4.14.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb) (2025.7.14)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.2)
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: absoluteking86 (absoluteking86-sarala-birla-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.21.0
# Run data is saved locally in <code>/content/wandb/run-20250731_231912-gppuf03u</code>
# Syncing run <strong><a href='https://wandb.ai/absoluteking86-sarala-birla-university/skip-autoencoder-compression/runs/gppuf03u' target="_blank">quiet-meadow-7</a></strong> to <a href='https://wandb.ai/absoluteking86-sarala-birla-university/skip-autoencoder-compression' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/absoluteking86-sarala-birla-university/skip-autoencoder-compression' target="_blank">https://wandb.ai/absoluteking86-sarala-birla-university/skip-autoencoder-compression</a>
#  View run at <a href='https://wandb.ai/absoluteking86-sarala-birla-university/skip-autoencoder-compression/runs/gppuf03u' target="_blank">https://wandb.ai/absoluteking86-sarala-birla-university/skip-autoencoder-compression/runs/gppuf03u</a>
# 100%|██████████| 2.64G/2.64G [02:01<00:00, 21.7MB/s]
# Training Autoencoder...
# wandb: WARNING Data passed to `wandb.Image` should consist of values in the range [0, 255], image data will be normalized to this range, but behavior will be removed in a future version of wandb.
# Autoencoder Epoch [1/5], Loss: 0.022095
# Autoencoder Epoch [2/5], Loss: 0.002779
# Autoencoder Epoch [3/5], Loss: 0.001628
# Autoencoder Epoch [4/5], Loss: 0.001198
# Autoencoder Epoch [5/5], Loss: 0.000963

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.rcParams['figure.dpi'] = 300  # High-res
mpl.rcParams['savefig.dpi'] = 300
plt.style.use('seaborn-v0_8-whitegrid')  # Better style
plt.rcParams.update({
    "font.size": 12,
    "axes.labelsize": 13,
    "axes.titlesize": 14,
    "legend.fontsize": 11,
    "lines.markersize": 6,
    "lines.linewidth": 2
})

# %%
# Train Latent Compressor

latent_compressor.train()
comp_optimizer = optim.Adam(latent_compressor.parameters(), lr=config.lr)   # use same lr from config
comp_criterion = nn.MSELoss()

print("\nTraining Latent Compressor...")
for epoch in range(config.epochs_comp):
    total_loss = 0.0
    for imgs, _ in trainloader:
        imgs = imgs.to(device)
        with torch.no_grad():
            _, e3 = autoencoder(imgs)  # latent features from trained AE (24x24 for STL-10)
        comp_optimizer.zero_grad()
        recon_e3 = latent_compressor(e3)
        loss = comp_criterion(recon_e3, e3)
        loss.backward()
        comp_optimizer.step()
        total_loss += loss.item() * imgs.size(0)

    avg_loss = total_loss / len(trainloader.dataset)
    print(f"Compressor Epoch [{epoch+1}/{config.epochs_comp}], Loss: {avg_loss:.6f}")

    # Log to wandb
    wandb.log({
        "train/compressor_loss": avg_loss,
        "epoch": config.epochs_ae + epoch + 1
    })
# Out:
# Training Latent Compressor...
# Compressor Epoch [1/10], Loss: 0.028530
# Compressor Epoch [2/10], Loss: 0.011539
# Compressor Epoch [3/10], Loss: 0.006137
# Compressor Epoch [4/10], Loss: 0.004677
# Compressor Epoch [5/10], Loss: 0.003951
# Compressor Epoch [6/10], Loss: 0.003540
# Compressor Epoch [7/10], Loss: 0.003071
# Compressor Epoch [8/10], Loss: 0.002953
# Compressor Epoch [9/10], Loss: 0.002596
# Compressor Epoch [10/10], Loss: 0.002410

# %%
wandb.watch(autoencoder, log="all", log_freq=100)
wandb.watch(latent_compressor, log="all", log_freq=100)

# %%
import time
import torch.nn.functional as F
import numpy as np
from torchvision.utils import save_image, make_grid
from skimage.metrics import structural_similarity as ssim

# PSNR helper
def psnr(img1, img2):
    mse = F.mse_loss(img1, img2)
    if mse == 0:
        return float('inf')
    return 20 * torch.log10(2.0 / torch.sqrt(mse))  # inputs normalized to [-1,1]

# Evaluation
autoencoder.eval()
latent_compressor.eval()

with torch.no_grad():
    imgs, _ = next(iter(testloader))
    imgs = imgs.to(device)

    # Encode
    e1 = autoencoder.enc1(imgs)
    e2 = autoencoder.enc2(e1)
    e3 = autoencoder.enc3(e2)

    # Compression
    start = time.time()
    z = latent_compressor.encoder(e3)
    comp_time = time.time() - start

    # Decompression
    start = time.time()
    decoded_e3 = latent_compressor.decoder(z)
    decomp_time = time.time() - start

    # Decode full image using reconstructed latent
    d1 = autoencoder.dec1(decoded_e3)
    d1_cat = torch.cat([d1, e2], 1)
    d2 = autoencoder.dec2(d1_cat)
    d2_cat = torch.cat([d2, e1], 1)
    recon_from_compressed = autoencoder.dec3(d2_cat)

    # AE recon (without compression)
    recon_img, _ = autoencoder(imgs)

    # SSIM (for 3-channel images)
    original_np = (imgs[0].permute(1, 2, 0).cpu().numpy() + 1) / 2
    recon_np = (recon_from_compressed[0].permute(1, 2, 0).cpu().numpy() + 1) / 2
    ssim_val = np.mean([
        ssim(original_np[:, :, c], recon_np[:, :, c], data_range=1.0)
        for c in range(3)
    ])

    # Save outputs
    save_image(imgs * 0.5 + 0.5, "output_images/original.png")
    save_image(recon_img * 0.5 + 0.5, "output_images/reconstructed.png")
    save_image(recon_from_compressed * 0.5 + 0.5, "output_images/recon_from_compressed.png")

    # PSNR
    psnr_recon = psnr(recon_img, imgs)
    psnr_compressed = psnr(recon_from_compressed, imgs)

    # Size info
    original_size_kb = e3.nelement() * 4 / 1024
    compressed_size_kb = z.nelement() * 4 / 1024
    total_pixels = imgs.shape[2] * imgs.shape[3] * imgs.shape[1]
    bpp = (z.nelement() * 32) / total_pixels  # bits per pixel

    # Error map for visualization
    error_map = torch.abs(imgs - recon_from_compressed)
    grid = make_grid(error_map * 5.0, nrow=4, normalize=True)

    # Log to WandB
    wandb.log({
        "eval/ssim": ssim_val,
        "eval/psnr_reconstruction": psnr_recon,
        "eval/psnr_compressed": psnr_compressed,
        "eval/bpp": bpp,
        "eval/compression_time_ms": comp_time * 1000,
        "eval/decompression_time_ms": decomp_time * 1000,
        "eval/compression_ratio": original_size_kb / compressed_size_kb,
        "eval/original_vs_recon": [
            wandb.Image(imgs[0] * 0.5 + 0.5, caption="Original"),
            wandb.Image(recon_img[0] * 0.5 + 0.5, caption="Recon (AE)"),
            wandb.Image(recon_from_compressed[0] * 0.5 + 0.5, caption="Recon (Compressed)")
        ],
        "eval/error_map": wandb.Image(grid, caption="Error map x5"),
        "eval/original_latent_size_kb": original_size_kb,
        "eval/compressed_latent_size_kb": compressed_size_kb,
        "eval/rate_distortion_point": wandb.plot.scatter(
            wandb.Table(data=[[compressed_size_kb, psnr_compressed]],
                        columns=["Compressed Size (KB)", "PSNR"]),
            "Compressed Size (KB)",
            "PSNR",
            title="Rate-Distortion"
        )
    })

    print(f"SSIM: {ssim_val:.4f}")
    print(f"PSNR (AE): {psnr_recon:.2f}")
    print(f"PSNR (Compressed): {psnr_compressed:.2f}")
    print(f"BPP: {bpp:.4f}")
    print(f"Compression ratio: {original_size_kb / compressed_size_kb:.2f}")
    print(f"Compression time: {comp_time * 1000:.2f} ms")
    print(f"Decompression time: {decomp_time * 1000:.2f} ms")
# Out:
# SSIM: 0.9197
# PSNR (AE): 37.06
# PSNR (Compressed): 22.24
# BPP: 42.6667
# Compression ratio: 64.00
# Compression time: 2.02 ms
# Decompression time: 0.55 ms

# %%
import numpy as np

# Quantization Function
class QuantizeSTE(torch.autograd.Function):
    @staticmethod
    def forward(ctx, input):
        return torch.round(input)

    @staticmethod
    def backward(ctx, grad_output):
        return grad_output

def quantize(input):
    return QuantizeSTE.apply(input)

# Evaluation & Compression Pipeline

autoencoder.eval()
latent_compressor.eval()

with torch.no_grad():
    imgs, _ = next(iter(testloader))
    imgs = imgs.to(device)

    # Get latent representations
    e1 = autoencoder.enc1(imgs)
    e2 = autoencoder.enc2(e1)
    e3 = autoencoder.enc3(e2)

    # Compress e3 to z
    z = latent_compressor.encoder(e3)
    print(f"Compressed shape (before quantization): {z.shape}")

    # Apply quantization
    z_quant = quantize(z)

    # Save to binary
    z_quant_int = torch.clamp(torch.round(z_quant * 127), -128, 127).to(torch.int8)
    z_np = z_quant_int.cpu().numpy()
    os.makedirs("output_images", exist_ok=True)
    z_np.tofile("output_images/compressed_latent.bin")

    quantized_size = os.path.getsize("output_images/compressed_latent.bin") / 1024
    print(f"Quantized latent saved as binary file (Size: {quantized_size:.2f} KB)")


import zlib

# Zlib Entropy Coding
z_bytes = z_np.tobytes()
zlib_compressed = zlib.compress(z_bytes, level=9)

# Save to file
with open("output_images/compressed_latent_zlib.bin", "wb") as f:
    f.write(zlib_compressed)

# Report size
zlib_size_kb = len(zlib_compressed) / 1024
print(f"Zlib-compressed latent size: {zlib_size_kb:.2f} KB")

#  Decode from Zlib for verification
with open("output_images/compressed_latent_zlib.bin", "rb") as f:
    zlib_loaded = f.read()

decompressed_bytes = zlib.decompress(zlib_loaded)
decompressed_np = np.frombuffer(decompressed_bytes, dtype=np.int8)
decompressed_tensor = torch.from_numpy(decompressed_np).float() / 127
decompressed_tensor = decompressed_tensor.view_as(z).to(device)

recon_ae, _ = autoencoder(imgs)

# Decode and save image from zlib-compressed
decoded_e3_zlib = latent_compressor.decoder(decompressed_tensor)
d1_zlib = autoencoder.dec1(decoded_e3_zlib)
d1_cat_zlib = torch.cat([d1_zlib, e2], 1)
d2_zlib = autoencoder.dec2(d1_cat_zlib)
d2_cat_zlib = torch.cat([d2_zlib, e1], 1)
recon_zlib = autoencoder.dec3(d2_cat_zlib)
save_image(recon_zlib * 0.5 + 0.5, "output_images/recon_from_zlib.png")
# Zlib Part ends here
print("Saved reconstruction from zlib-compressed latent.")

# Load from binary and decompress
loaded_np = np.fromfile("output_images/compressed_latent.bin", dtype=np.int8)
loaded_tensor = torch.from_numpy(loaded_np).float() / 127  # Rescale to [-1, 1]
loaded_tensor = loaded_tensor.view_as(z).to(device)

decoded_e3 = latent_compressor.decoder(loaded_tensor)

# Final decoding pipeline
d1 = autoencoder.dec1(decoded_e3)
d1_cat = torch.cat([d1, e2], 1)
d2 = autoencoder.dec2(d1_cat)
d2_cat = torch.cat([d2, e1], 1)
recon_from_bin = autoencoder.dec3(d2_cat)

# Save all images
save_image(imgs * 0.5 + 0.5, "output_images/original.png")
recon_img, _ = autoencoder(imgs)
save_image(recon_img * 0.5 + 0.5, "output_images/reconstructed.png")
save_image(recon_from_bin * 0.5 + 0.5, "output_images/recon_from_loaded_compressed.png")

# Size info
original_size = e3.nelement() * 4  # float32
compressed_size = z.nelement() * 4
print(f"Original e3 size: {original_size / 1024:.2f} KB")
print(f"Compressed z (float32) size: {compressed_size / 1024:.2f} KB")
# Out:
# Compressed shape (before quantization): torch.Size([16, 64, 6, 6])
# Quantized latent saved as binary file (Size: 36.00 KB)
# Zlib-compressed latent size: 2.36 KB
# Saved reconstruction from zlib-compressed latent.
# /tmp/ipython-input-3759548929.py:67: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   decompressed_tensor = torch.from_numpy(decompressed_np).float() / 127
# Original e3 size: 9216.00 KB
# Compressed z (float32) size: 144.00 KB

# %%
# Improved Quantization using Min-Max Scaling
z_min = z.min()
z_max = z.max()

# Normalize z to [0, 1], then scale to [0, 255]
z_scaled = (z - z_min) / (z_max - z_min)
z_quantized = torch.round(z_scaled * 255).to(torch.uint8)

# Save quantized latent
z_np = z_quantized.cpu().numpy()
os.makedirs("output_images", exist_ok=True)
z_np.tofile("output_images/compressed_latent.bin")

# Save min and max for dequantization
with open("output_images/quant_meta.txt", "w") as f:
    f.write(f"{z_min.item()},{z_max.item()}")


print("Quantized latent saved as binary file: output_images/compressed_latent.bin")
# Out:
# Quantized latent saved as binary file: output_images/compressed_latent.bin

# %%
# Calculate and print size of quantized latent in KB
quantized_size = os.path.getsize("output_images/compressed_latent.bin") / 1024
print(f"Quantized latent binary size: {quantized_size:.2f} KB")
# Load quantized latent
loaded_np = np.fromfile("output_images/compressed_latent.bin", dtype=np.uint8)

# Load min/max values
with open("output_images/quant_meta.txt", "r") as f:
    z_min, z_max = map(float, f.read().strip().split(","))

# Dequantize to original range
z_scaled = torch.from_numpy(loaded_np).float() / 255
z_dequant = z_scaled * (z_max - z_min) + z_min
loaded_tensor = z_dequant.view_as(z).to(device)


# Decode latent as usual
with torch.no_grad():
    decoded_e3_loaded = latent_compressor.decoder(loaded_tensor)

    d1_loaded = autoencoder.dec1(decoded_e3_loaded)
    d1_cat_loaded = torch.cat([d1_loaded, e2], 1)
    d2_loaded = autoencoder.dec2(d1_cat_loaded)
    d2_cat_loaded = torch.cat([d2_loaded, e1], 1)
    recon_loaded = autoencoder.dec3(d2_cat_loaded)

    save_image(recon_loaded * 0.5 + 0.5, "output_images/recon_from_loaded_compressed.png")
    print("Saved reconstructed image from loaded compressed latent.")
# Out:
# Quantized latent binary size: 36.00 KB
# Saved reconstructed image from loaded compressed latent.

# %%
import torch.nn.functional as F
import math

def calculate_psnr(img1, img2):
    mse = F.mse_loss(img1, img2)
    if mse == 0:
        return float('inf')
    psnr = 20 * math.log10(1.0) - 10 * math.log10(mse.item())
    return psnr

# Evaluation with Metrics
autoencoder.eval()
latent_compressor.eval()

with torch.no_grad():
    imgs, _ = next(iter(testloader))
    imgs = imgs.to(device)

    # Original encoding
    e1 = autoencoder.enc1(imgs)
    e2 = autoencoder.enc2(e1)
    e3 = autoencoder.enc3(e2)

    # Latent compression
    z = latent_compressor.encoder(e3)
    # Compute min and max from the latent
    z_min = z.min()
    z_max = z.max()

    # Scale z to [0, 1] and quantize to uint8
    z_scaled = (z - z_min) / (z_max - z_min + 1e-8)  # add epsilon for stability
    z_quantized = torch.round(z_scaled * 255).to(torch.uint8)

    # Save quantized latent and metadata
    z_np = z_quantized.cpu().numpy()
    with open("output_images/quant_meta.txt", "w") as f:
        f.write(f"{z_min.item()},{z_max.item()}")


    # Save zlib compressed version
    import zlib
    z_bytes = z_np.tobytes()
    zlib_compressed = zlib.compress(z_bytes, level=9)

    # Decompress for reconstruction
    decompressed_bytes = zlib.decompress(zlib_compressed)
    decompressed_np = np.frombuffer(decompressed_bytes, dtype=np.uint8)

    # Read min/max
    with open("output_images/quant_meta.txt", "r") as f:
        z_min, z_max = map(float, f.read().strip().split(","))

    # Dequantize to float32
    z_scaled = torch.from_numpy(decompressed_np.copy()).float() / 255
    decompressed_tensor = z_scaled * (z_max - z_min) + z_min
    decompressed_tensor = decompressed_tensor.view_as(z).to(device)

    # Decode
    decoded_e3 = latent_compressor.decoder(decompressed_tensor)
    d1 = autoencoder.dec1(decoded_e3)
    d1_cat = torch.cat([d1, e2], 1)
    d2 = autoencoder.dec2(d1_cat)
    d2_cat = torch.cat([d2, e1], 1)
    recon_zlib = autoencoder.dec3(d2_cat)

    # PSNR
    psnr_recon = calculate_psnr(imgs, recon_zlib)
    print(f"PSNR (reconstruction from zlib compressed latent): {psnr_recon:.2f} dB")

    # Sizes
    original_e3_size_kb = e3.nelement() * 4 / 1024  # float32
    compressed_z_kb = z.nelement() * 4 / 1024       # float32
    quantized_z_kb = z_quantized.nelement() / 1024  # uint8 = 1 byte per element
    zlib_kb = len(zlib_compressed) / 1024

    ratio = original_e3_size_kb / zlib_kb

    print(f"Original latent size: {original_e3_size_kb:.2f} KB")
    print(f"Compressed (z float32): {compressed_z_kb:.2f} KB")
    print(f"Quantized (uint8): {quantized_z_kb:.2f} KB")
    print(f"Zlib compressed size: {zlib_kb:.2f} KB")
    print(f"Effective compression ratio: {ratio:.2f}x")
# Out:
# PSNR (reconstruction from zlib compressed latent): 16.22 dB
# Original latent size: 9216.00 KB
# Compressed (z float32): 144.00 KB
# Quantized (uint8): 36.00 KB
# Zlib compressed size: 20.35 KB
# Effective compression ratio: 452.82x

# %%
from torchvision.utils import make_grid, save_image

with torch.no_grad():
    recon_ae, _ = autoencoder(imgs)  # recon_ae shape: [16, 3, 32, 32]
    recon_ae = recon_ae * 0.5 + 0.5
    recon_zlib = recon_zlib * 0.5 + 0.5
    imgs_vis = imgs * 0.5 + 0.5

image_grid = make_grid(
    torch.cat([imgs_vis, recon_ae, recon_zlib], dim=0),
    nrow=imgs.size(0),
    padding=2
)
save_image(image_grid, "output_images/comparison_grid.png")

# %%
import matplotlib.pyplot as plt
import numpy as np

error_map = torch.abs(imgs_vis - recon_zlib).mean(dim=1, keepdim=True)
save_image(error_map, "output_images/error_map.png")

# %%
import torch
from torchvision.utils import save_image, make_grid
import matplotlib.pyplot as plt

# Calculate absolute error map (grayscale)
error_map = torch.abs(imgs_vis - recon_zlib).mean(dim=1, keepdim=True)  # [B,1,H,W]

# Save error map images grid
save_image(error_map, "output_images/error_map.png")
print("Saved error map image.")

# Display error map grid using matplotlib
grid_img = make_grid(error_map, nrow=4, normalize=True)  # Normalize for better visibility

plt.figure(figsize=(8, 8))
plt.imshow(grid_img.permute(1, 2, 0).cpu(), cmap='gray')
plt.axis('off')
plt.title("Error Map Grid (Absolute Difference)")
plt.show()
# Out:
# Saved error map image.

# %%
wandb.log({
    "eval/rate_distortion_point": wandb.plot.scatter(
        wandb.Table(data=[[compressed_size_kb, -psnr_compressed]], columns=["Compressed Size (KB)", "-PSNR"]),
        "Compressed Size (KB)",
        "-PSNR",
        title="Rate-Distortion Curve (Negative PSNR)"
    )
})

# %%
wandb.log({
    "compression/psnr": psnr_compressed.item(),
    "compression/size_kb": compressed_size_kb,
    "compression/error_map": wandb.Image(grid, caption="|Original - CompressedRecon| x5")
})

# %%
# !pip install pytorch-msssim
# Out:
# Collecting pytorch-msssim
#   Downloading pytorch_msssim-1.0.0-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from pytorch-msssim) (2.6.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->pytorch-msssim) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch->pytorch-msssim) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->pytorch-msssim) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->pytorch-msssim) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->pytorch-msssim) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch->pytorch-msssim)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch->pytorch-msssim)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch->pytorch-msssim)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch->pytorch-msssim)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch->pytorch-msssim)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch->pytorch-msssim)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch->pytorch-msssim)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch->pytorch-msssim)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch->pytorch-msssim)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->pytorch-msssim) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->pytorch-msssim) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->pytorch-msssim) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch->pytorch-msssim)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->pytorch-msssim) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->pytorch-msssim) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->pytorch-msssim) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->pytorch-msssim) (3.0.2)
# Downloading pytorch_msssim-1.0.0-py3-none-any.whl (7.7 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 43.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 54.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 51.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 3.0 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.4 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.9 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 58.3 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, pytorch-msssim
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 pytorch-msssim-1.0.0

# %%
import torch
import torch.nn.functional as F
import numpy as np
import time
from pytorch_msssim import ssim
import wandb
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt

# Utilities
def calculate_psnr(img1, img2):
    mse = F.mse_loss(img1, img2, reduction='mean')
    return float('inf') if mse.item() == 0 else (20 * torch.log10(torch.tensor(1.0)) - 10 * torch.log10(mse)).item()

def calculate_bpp(compressed_bits, image_shape):
    batch_size, _, h, w = image_shape
    return compressed_bits / (batch_size * h * w)

def make_image_grid(imgs_list, nrow=4):
    """
    Make a grid of images side by side for comparison.
    imgs_list: list of torch.Tensor images [B, C, H, W]
    Returns: grid tensor with imgs concatenated side by side for each batch
    """

    import torchvision.utils as vutils
    # Concatenate along width: stack images per sample horizontally, then stack vertically batches
    concatenated = torch.cat(imgs_list, dim=3)  # concat on width
    grid = vutils.make_grid(concatenated, nrow=nrow, normalize=True, scale_each=True)
    return grid

def get_error_map(img1, img2):
    """Absolute error per pixel, normalized to [0,1]"""
    err = torch.abs(img1 - img2)
    err = err / err.max()
    return err

# Setup
wandb.init(project="latent-compression", name="rd-curve-experiment-with-visuals")

autoencoder.eval()
latent_compressor.eval()

quant_levels = [64, 127, 255]
results = []

for quant in quant_levels:
    for imgs, _ in tqdm(testloader, desc=f"Quant={quant}"):
        imgs = imgs.to(device)

        with torch.no_grad():
            #  AE encode and reconstruct
            e1 = autoencoder.enc1(imgs)
            e2 = autoencoder.enc2(e1)
            e3 = autoencoder.enc3(e2)
            z = latent_compressor.encoder(e3)
            z_quant = quantize(z)

            # Uncompressed AE reconstruction for baseline
            decoded_e3_ae = latent_compressor.decoder(z_quant)
            d1_ae = autoencoder.dec1(decoded_e3_ae)
            d2_ae = autoencoder.dec2(torch.cat([d1_ae, e2], dim=1))
            recon_ae = autoencoder.dec3(torch.cat([d2_ae, e1], dim=1))

            # Quantize to int8 using current quant level
            z_int = torch.clamp(torch.round(z_quant * quant), -quant, quant).to(torch.int8)
            z_np = z_int.cpu().numpy()

            # Compression
            start_c = time.time()
            zlib_compressed = zlib.compress(z_np.tobytes(), level=9)
            comp_time = (time.time() - start_c) * 1000

            # Decompression
            start_d = time.time()
            z_np_decomp = np.frombuffer(zlib.decompress(zlib_compressed), dtype=np.int8)
            decomp_time = (time.time() - start_d) * 1000

            z_t_decomp = torch.from_numpy(z_np_decomp.copy()).float() / quant
            z_t_decomp = z_t_decomp.view_as(z).to(device)

            # Decode compressed
            decoded_e3 = latent_compressor.decoder(z_t_decomp)
            d1 = autoencoder.dec1(decoded_e3)
            d2 = autoencoder.dec2(torch.cat([d1, e2], dim=1))
            recon = autoencoder.dec3(torch.cat([d2, e1], dim=1))

            # Metrics
            psnr_ae = calculate_psnr(imgs, recon_ae)
            psnr = calculate_psnr(imgs, recon)
            ssim_val = ssim(imgs, recon, data_range=1.0).item()
            bpp = calculate_bpp(len(zlib_compressed) * 8, imgs.shape)
            size_kb = len(zlib_compressed) / 1024
            original_kb = e3.nelement() * 4 / 1024  # float32
            ratio = original_kb / size_kb

            results.append({
                "quant_level": quant,
                "PSNR_AE": psnr_ae,
                "PSNR_Compressed": psnr,
                "SSIM": ssim_val,
                "BPP": bpp,
                "Compressed_KB": size_kb,
                "Original_KB": original_kb,
                "Compression_Ratio": ratio,
                "Compression_Time_ms": comp_time,
                "Decompression_Time_ms": decomp_time,
            })

            # Visual logging per batch: sample first 4 images to keep size reasonable
            imgs_viz = imgs[:4]
            recon_ae_viz = recon_ae[:4]
            recon_viz = recon[:4]

            # Create side-by-side grid: Original | AE Recon | Compressed Recon
            grid_img = make_image_grid([imgs_viz, recon_ae_viz, recon_viz], nrow=4)

            # Error map between Original and Compressed Recon
            error_map = get_error_map(imgs_viz, recon_viz)
            error_grid = make_image_grid([error_map], nrow=4)

            # Log images and scalars to WandB
            wandb.log({
                f"Visuals/Quant_{quant}/Image_Comparison": wandb.Image(grid_img, caption=f"Original | AE Recon | Compressed Recon (Quant {quant})"),
                f"Visuals/Quant_{quant}/Error_Map": wandb.Image(error_grid, caption=f"Error Map (Quant {quant})"),
                f"Metrics/Quant_{quant}/PSNR_AE": psnr_ae,
                f"Metrics/Quant_{quant}/PSNR_Compressed": psnr,
                f"Metrics/Quant_{quant}/SSIM": ssim_val,
                f"Metrics/Quant_{quant}/BPP": bpp,
                f"Metrics/Quant_{quant}/Compression_Time_ms": comp_time,
                f"Metrics/Quant_{quant}/Decompression_Time_ms": decomp_time,
            })

# Prepare WandB tables for RD plots
rd_table = wandb.Table(columns=["Quant", "BPP", "PSNR_Compressed", "SSIM", "Compression_Time_ms"])
for r in results:
    rd_table.add_data(r["quant_level"], r["BPP"], r["PSNR_Compressed"], r["SSIM"], r["Compression_Time_ms"])

wandb.log({
    "RD_Curve_PSNR": wandb.plot.line(rd_table, "BPP", "PSNR_Compressed", title="Rate–Distortion: PSNR"),
    "RD_Curve_SSIM": wandb.plot.line(rd_table, "BPP", "SSIM", title="Rate–Distortion: SSIM"),
    "Compression_Time_vs_BPP": wandb.plot.line(rd_table, "BPP", "Compression_Time_ms", title="Compression Time vs BPP"),
})

# Save CSV for reporting
df = pd.DataFrame(results)
df.to_csv("output_images/rate_distortion_metrics.csv", index=False)

# Print markdown table for quick report copy-paste
print("\n### Rate-Distortion Metrics Table (Markdown)\n")
print("| Quant Level | BPP | PSNR (Compressed) | SSIM | Compression Ratio | Comp Time (ms) | Decomp Time (ms) |")
print("|-------------|-----|-------------------|------|-------------------|---------------|------------------|")
for r in results:
    print(f"| {r['quant_level']} | {r['BPP']:.4f} | {r['PSNR_Compressed']:.2f} | {r['SSIM']:.4f} | {r['Compression_Ratio']:.2f} | {r['Compression_Time_ms']:.2f} | {r['Decompression_Time_ms']:.2f} |")
# Out:
# Finishing previous runs because reinit is set to 'default'.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>compression/psnr</td><td>▁</td></tr><tr><td>compression/size_kb</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>eval/bpp</td><td>▁</td></tr><tr><td>eval/compressed_latent_size_kb</td><td>▁</td></tr><tr><td>eval/compression_ratio</td><td>▁</td></tr><tr><td>eval/compression_time_ms</td><td>▁</td></tr><tr><td>eval/decompression_time_ms</td><td>▁</td></tr><tr><td>eval/original_latent_size_kb</td><td>▁</td></tr><tr><td>eval/psnr_compressed</td><td>▁</td></tr><tr><td>eval/psnr_reconstruction</td><td>▁</td></tr><tr><td>eval/ssim</td><td>▁</td></tr><tr><td>train/ae_loss</td><td>█▂▁▁▁</td></tr><tr><td>train/compressor_loss</td><td>█▃▂▂▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>compression/psnr</td><td>22.24402</td></tr><tr><td>compression/size_kb</td><td>144</td></tr><tr><td>epoch</td><td>15</td></tr><tr><td>eval/bpp</td><td>42.66667</td></tr><tr><td>eval/compressed_latent_size_kb</td><td>144</td></tr><tr><td>eval/compression_ratio</td><td>64</td></tr><tr><td>eval/compression_time_ms</td><td>2.01893</td></tr><tr><td>eval/decompression_time_ms</td><td>0.55194</td></tr><tr><td>eval/original_latent_size_kb</td><td>9216</td></tr><tr><td>eval/psnr_compressed</td><td>22.24402</td></tr><tr><td>eval/psnr_reconstruction</td><td>37.05806</td></tr><tr><td>eval/ssim</td><td>0.91968</td></tr><tr><td>train/ae_loss</td><td>0.00096</td></tr><tr><td>train/compressor_loss</td><td>0.00241</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">quiet-meadow-7</strong> at: <a href='https://wandb.ai/absoluteking86-sarala-birla-university/skip-autoencoder-compression/runs/gppuf03u' target="_blank">https://wandb.ai/absoluteking86-sarala-birla-university/skip-autoencoder-compression/runs/gppuf03u</a><br> View project at: <a href='https://wandb.ai/absoluteking86-sarala-birla-university/skip-autoencoder-compression' target="_blank">https://wandb.ai/absoluteking86-sarala-birla-university/skip-autoencoder-compression</a><br>Synced 5 W&B file(s), 17 media file(s), 4 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250731_231912-gppuf03u/logs</code>
# Tracking run with wandb version 0.21.0
# Run data is saved locally in <code>/content/wandb/run-20250731_232710-o74lixoh</code>
# Syncing run <strong><a href='https://wandb.ai/absoluteking86-sarala-birla-university/latent-compression/runs/o74lixoh' target="_blank">rd-curve-experiment-with-visuals</a></strong> to <a href='https://wandb.ai/absoluteking86-sarala-birla-university/latent-compression' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/absoluteking86-sarala-birla-university/latent-compression' target="_blank">https://wandb.ai/absoluteking86-sarala-birla-university/latent-compression</a>
#  View run at <a href='https://wandb.ai/absoluteking86-sarala-birla-university/latent-compression/runs/o74lixoh' target="_blank">https://wandb.ai/absoluteking86-sarala-birla-university/latent-compression/runs/o74lixoh</a>
# Quant=64: 100%|██████████| 500/500 [01:14<00:00,  6.72it/s]
# Quant=127: 100%|██████████| 500/500 [01:01<00:00,  8.09it/s]
# Quant=255: 100%|██████████| 500/500 [01:02<00:00,  8.00it/s]
# ### Rate-Distortion Metrics Table (Markdown)
#
# | Quant Level | BPP | PSNR (Compressed) | SSIM | Compression Ratio | Comp Time (ms) | Decomp Time (ms) |
# |-------------|-----|-------------------|------|-------------------|---------------|------------------|
# | 64 | 0.1313 | 18.77 | 0.6700 | 3898.05 | 22.93 | 0.13 |
# | 64 | 0.1416 | 18.64 | 0.7294 | 3615.78 | 26.47 | 0.13 |
# | 64 | 0.1358 | 18.68 | 0.7154 | 3770.35 | 23.20 | 0.11 |
# | 64 | 0.1397 | 18.81 | 0.6865 | 3664.93 | 26.79 | 0.13 |
# | 64 | 0.1406 | 19.02 | 0.7590 | 3640.89 | 26.51 | 0.13 |
# | 255 | 0.1315 | 24.91 | 0.8967 | 3893.23 | 14.90 | 0.08 |
# | 255 | 0.1363 | 24.61 | 0.8942 | 3756.84 | 16.48 | 0.09 |
# | 255 | 0.1398 | 25.44 | 0.9058 | 3663.50 | 16.59 | 0.11 |
# | 255 | 0.1452 | 24.71 | 0.8907 | 3525.28 | 17.77 | 0.09 |
# | 255 | 0.1368 | 24.76 | 0.9069 | 3741.94 | 15.81 | 0.08 |
# | 255 | 0.1334 | 25.39 | 0.8996 | 3837.81 | 16.28 | 0.09 |
# | 255 | 0.1431 | 25.27 | 0.9083 | 3578.76 | 17.13 | 0.09 |
# | 255 | 0.1419 | 24.90 | 0.8898 | 3607.49 | 16.73 | 0.09 |
# | 255 | 0.1340 | 25.30 | 0.9087 | 3820.72 | 14.56 | 0.08 |
# | 255 | 0.1389 | 24.72 | 0.8876 | 3686.40 | 15.83 | 0.11 |
# | 255 | 0.1351 | 24.11 | 0.8714 | 3790.03 | 15.81 | 0.11 |
# | 255 | 0.1361 | 24.65 | 0.9128 | 3762.83 | 16.06 | 0.11 |
# | 255 | 0.1421 | 24.13 | 0.9050 | 3603.35 | 16.97 | 0.09 |
# | 255 | 0.1275 | 25.14 | 0.9050 | 4014.11 | 14.65 | 0.10 |
# | 255 | 0.1363 | 25.38 | 0.8923 | 3756.84 | 16.09 | 0.08 |
# | 255 | 0.1406 | 24.81 | 0.8851 | 3640.89 | 17.67 | 0.09 |
# | 255 | 0.1356 | 24.57 | 0.8779 | 3776.38 | 15.71 | 0.08 |
# | 255 | 0.1404 | 24.69 | 0.9049 | 3647.93 | 16.32 | 0.09 |
# | 255 | 0.1443 | 25.14 | 0.9028 | 3549.15 | 17.69 | 0.09 |
# | 255 | 0.1294 | 25.18 | 0.8940 | 3955.23 | 14.44 | 0.09 |
# | 255 | 0.1345 | 24.67 | 0.8987 | 3806.85 | 19.74 | 0.09 |
# | 255 | 0.1397 | 24.58 | 0.8932 | 3664.93 | 15.86 | 0.11 |

# %%
# ===================== HIGH RESOLUTION FIGURE 4 =====================
import torchvision.utils as vutils
import os

os.makedirs("output_images", exist_ok=True)

GRID_SIZE = 400  # make the figure big for the paper
quant_levels = [64, 127, 255]

print("\n📸 Saving high-resolution grids for the paper...\n")

# Get one batch of images for clean visualization
imgs, _ = next(iter(testloader))
imgs = imgs[:8].to(device)

for quant in quant_levels:
    with torch.no_grad():
        # Forward pass through the model again (same as your main loop)
        e1 = autoencoder.enc1(imgs)
        e2 = autoencoder.enc2(e1)
        e3 = autoencoder.enc3(e2)
        z = latent_compressor.encoder(e3)
        z_quant = quantize(z)

        # AE reconstruction
        decoded_e3_ae = latent_compressor.decoder(z_quant)
        d1_ae = autoencoder.dec1(decoded_e3_ae)
        d2_ae = autoencoder.dec2(torch.cat([d1_ae, e2], dim=1))
        recon_ae = autoencoder.dec3(torch.cat([d2_ae, e1], dim=1))

        # Compressed reconstruction
        z_int = torch.clamp(torch.round(z_quant * quant), -quant, quant).to(torch.int8)
        z_np = z_int.cpu().numpy()
        z_np_decomp = np.frombuffer(zlib.decompress(zlib.compress(z_np.tobytes(), level=9)), dtype=np.int8)
        z_t_decomp = torch.from_numpy(z_np_decomp.copy()).float() / quant
        z_t_decomp = z_t_decomp.view_as(z).to(device)

        decoded_e3 = latent_compressor.decoder(z_t_decomp)
        d1 = autoencoder.dec1(decoded_e3)
        d2 = autoencoder.dec2(torch.cat([d1, e2], dim=1))
        recon = autoencoder.dec3(torch.cat([d2, e1], dim=1))

    # Denormalize images for display
    originals = imgs.cpu().clamp(0, 1)
    recon_ae = recon_ae.cpu().clamp(0, 1)
    recon = recon.cpu().clamp(0, 1)

    # Combine into a single grid
    grid = vutils.make_grid(
        torch.cat([originals, recon_ae, recon], dim=0),
        nrow=originals.size(0),
        padding=4,
        pad_value=1
    )

    # Save figure only (no wandb)
    fig_path = f"output_images/figure4_visual_comparison_q{quant}.png"
    plt.figure(figsize=(GRID_SIZE/100, GRID_SIZE/300 * 3))
    plt.imshow(grid.permute(1, 2, 0).numpy())
    plt.axis('off')
    plt.savefig(fig_path, bbox_inches='tight', pad_inches=0, dpi=300)
    plt.close()

    print(f"✅ Saved: {fig_path}")

print("\n🎯 All high-resolution images ready in `output_images/` folder!\n")
# Out:
# 📸 Saving high-resolution grids for the paper...
#
# ✅ Saved: output_images/figure4_visual_comparison_q64.png
# ✅ Saved: output_images/figure4_visual_comparison_q127.png
# ✅ Saved: output_images/figure4_visual_comparison_q255.png
#
# 🎯 All high-resolution images ready in `output_images/` folder!

# %%
df.to_csv("rate_distortion_metrics.csv", index=False)

# %%
import pandas as pd

# Load the data
df = pd.read_csv("rate_distortion_metrics.csv")

# Display column names to check
print(df.columns)

# Group by 'quant_level' and calculate mean and std for relevant columns
summary = df.groupby('quant_level').agg({
    'BPP': ['mean', 'std'],
    'PSNR_Compressed': ['mean', 'std'],
    'SSIM': ['mean', 'std'],
    'Compression_Ratio': ['mean', 'std'],
    'Compression_Time_ms': ['mean', 'std'],
    'Decompression_Time_ms': ['mean', 'std']
}).reset_index()

# Flatten MultiIndex columns
summary.columns = ['_'.join(col).strip('_') for col in summary.columns.values]

print(summary)

# Optional: save summary to csv
summary.to_csv("summary_rate_distortion_metrics.csv", index=False)
# Out:
# Index(['quant_level', 'PSNR_AE', 'PSNR_Compressed', 'SSIM', 'BPP',
#        'Compressed_KB', 'Original_KB', 'Compression_Ratio',
#        'Compression_Time_ms', 'Decompression_Time_ms'],
#       dtype='object')
#    quant_level  BPP_mean   BPP_std  PSNR_Compressed_mean  PSNR_Compressed_std  \
# 0           64  0.137445  0.004589             18.815718             0.287550
# 1          127  0.137222  0.004558             18.815718             0.287550
# 2          255  0.137222  0.004558             25.020331             0.500645
#
#    SSIM_mean  SSIM_std  Compression_Ratio_mean  Compression_Ratio_std  \
# 0   0.731727  0.028109             3729.279154             125.039525
# 1   0.731727  0.028109             3735.311941             124.514281
# 2   0.896841  0.013529             3735.311941             124.514281
#
#    Compression_Time_ms_mean  Compression_Time_ms_std  \
# 0                 25.636744                 8.570138
# 1                 17.510171                 2.541697
# 2                 17.691315                 2.806249
#
#    Decompression_Time_ms_mean  Decompression_Time_ms_std
# 0                    0.136461                   0.336405
# 1                    0.107543                   0.073227
# 2                    0.104423                   0.022233

# %%
import matplotlib.pyplot as plt

plt.errorbar(summary['quant_level'], summary['PSNR_Compressed_mean'],
             yerr=summary['PSNR_Compressed_std'], label='PSNR', marker='o')
plt.xlabel('Quantization Level')
plt.ylabel('PSNR (dB)')
plt.title('PSNR vs Quantization Level')
plt.grid(True)
plt.show()

# %%
fig, ax1 = plt.subplots()

color = 'tab:blue'
ax1.set_xlabel('Quantization Level')
ax1.set_ylabel('BPP', color=color)
ax1.plot(summary['quant_level'], summary['BPP_mean'], color=color, marker='o')
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Compression Ratio', color=color)
ax2.plot(summary['quant_level'], summary['Compression_Ratio_mean'], color=color, marker='s')
ax2.tick_params(axis='y', labelcolor=color)

plt.title("BPP and Compression Ratio vs Quantization Level")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
from PIL import Image
import io
import os
import torch
import torchvision.transforms as T
import numpy as np

jpeg_results = []

jpeg_qualities = [10, 30, 50, 70, 90]

for q in jpeg_qualities:
    bpp_list, psnr_list = [], []

    for imgs, _ in testloader:
        imgs = imgs.to('cpu')  # Use CPU for PIL
        for img in imgs:
            img = T.ToPILImage()(img * 0.5 + 0.5)  # Unnormalize
            with io.BytesIO() as buffer:
                img.save(buffer, format='JPEG', quality=q)
                jpeg_bytes = buffer.getvalue()
                size_bytes = len(jpeg_bytes)

            # Decode
            with io.BytesIO(jpeg_bytes) as buffer:
                img_jpeg = Image.open(buffer)
                img_jpeg = T.ToTensor()(img_jpeg)

            # Crop or resize if needed to match original
            img_jpeg = img_jpeg[:3, :, :]
            img_tensor = (T.ToTensor()(img) * 0.5 + 0.5).clamp(0, 1)
            img_jpeg = img_jpeg.clamp(0, 1)

            # PSNR
            mse = F.mse_loss(img_jpeg, img_tensor)
            psnr = float('inf') if mse == 0 else 20 * torch.log10(torch.tensor(1.0)) - 10 * torch.log10(mse)
            psnr_list.append(psnr.item())

            # BPP = (bits / pixels)
            h, w = img_tensor.shape[1:]
            bpp = (size_bytes * 8) / (h * w)
            bpp_list.append(bpp)

        break  # Optional: test only on one batch

    jpeg_results.append({
        'quality': q,
        'bpp': np.mean(bpp_list),
        'psnr': np.mean(psnr_list)
    })

# %%
# AE model summary
ae_bpp = summary['BPP_mean']
ae_psnr = summary['PSNR_Compressed_mean']
ae_labels = summary['quant_level']

# JPEG data
jpeg_bpp = [r['bpp'] for r in jpeg_results]
jpeg_psnr = [r['psnr'] for r in jpeg_results]
jpeg_labels = [f'JPEG Q={r["quality"]}' for r in jpeg_results]

# Plot
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
plt.plot(ae_bpp, ae_psnr, '-o', label="Latent Compression (AE)")
plt.plot(jpeg_bpp, jpeg_psnr, '-s', label="JPEG", color='orange')

# Annotate points
for i, txt in enumerate(ae_labels):
    plt.annotate(f'Q={txt}', (ae_bpp[i], ae_psnr[i]), fontsize=8)

for i, txt in enumerate(jpeg_labels):
    plt.annotate(txt, (jpeg_bpp[i], jpeg_psnr[i]), fontsize=8, color='orange')

plt.xlabel("Bits Per Pixel (BPP)")
plt.ylabel("PSNR (dB)")
plt.title("Rate–Distortion Comparison: AE vs JPEG")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.savefig("rd_curve_ae_vs_jpeg.png")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib

# Set style and font for publication
sns.set(style="whitegrid", font_scale=1.2)
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

plt.figure(figsize=(9, 6))

# Plot AE results
plt.plot(ae_bpp, ae_psnr, '-o', label="LC-Net (AE-based)", color='steelblue', linewidth=2.5, markersize=7)

# Plot JPEG results
plt.plot(jpeg_bpp, jpeg_psnr, '-s', label="JPEG", color='darkorange', linewidth=2.5, markersize=6)

# Annotate AE points
for i, txt in enumerate(ae_labels):
    plt.annotate(f"Q={txt}", (ae_bpp[i]+0.02, ae_psnr[i]+0.2), fontsize=9, color='steelblue')

# Annotate JPEG points
for i, txt in enumerate(jpeg_labels):
    plt.annotate(txt, (jpeg_bpp[i]+0.05, jpeg_psnr[i]+0.15), fontsize=9, color='darkorange')

# Labels and title
plt.xlabel("Bits Per Pixel (BPP)", fontsize=13)
plt.ylabel("PSNR (dB)", fontsize=13)
plt.title("Rate–Distortion Curve: LC-Net vs JPEG", fontsize=14)

# Legend and layout
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend(loc="lower right", fontsize=11)
plt.tight_layout()

# Save as SVG (vector format)
plt.savefig("rd_curve_ae_vs_jpeg.svg", format='svg')

# Show plot
plt.show()

# %%
import wandb
import torch
import torch.nn.functional as F
from PIL import Image
import torchvision.transforms as T
import io
import numpy as np
import matplotlib.pyplot as plt
from skimage.metrics import structural_similarity as sk_ssim

# Initialize wandb
wandb.init(
    project="latent-compression-vs-jpeg",
    name="AE vs JPEG - Rate Distortion with SSIM",
    config={
        "model": "AE latent compression",
        "baseline": "JPEG",
        "dataset": "CIFAR-10"
    }
)

ae_bpp = summary['BPP_mean'].tolist()
ae_psnr = summary['PSNR_Compressed_mean'].tolist()
ae_ssim = summary['SSIM_mean'].tolist()
ae_labels = summary['quant_level'].tolist()

# JPEG evaluation loop
jpeg_results = []
jpeg_qualities = [10, 30, 50, 70, 90]

for q in jpeg_qualities:
    bpp_list, psnr_list, ssim_list = [], [], []

    for imgs, _ in testloader:
        imgs = imgs.cpu()
        for img in imgs:
            # Convert to PIL and compress as JPEG
            pil = T.ToPILImage()(img * 0.5 + 0.5)
            with io.BytesIO() as buf:
                pil.save(buf, format='JPEG', quality=q)
                jpeg_bytes = buf.getvalue()
            size_bytes = len(jpeg_bytes)

            # Load JPEG back to tensor
            pil_jpeg = Image.open(io.BytesIO(jpeg_bytes)).convert("RGB")
            img_jpeg = T.ToTensor()(pil_jpeg).clamp(0, 1)

            # Original tensor
            img_tensor = T.ToTensor()(pil).clamp(0, 1)

            # PSNR
            mse = F.mse_loss(img_jpeg, img_tensor)
            psnr = float('inf') if mse == 0 else 20 * torch.log10(torch.tensor(1.0)) - 10 * torch.log10(mse)
            psnr_list.append(psnr.item())

            # SSIM (channel-wise averaged)
            orig_np = img_tensor.permute(1, 2, 0).numpy()
            jpeg_np = img_jpeg.permute(1, 2, 0).numpy()
            ssim_val = np.mean([
                sk_ssim(orig_np[:, :, c], jpeg_np[:, :, c], data_range=1.0)
                for c in range(3)
            ])
            ssim_list.append(ssim_val)

            # BPP
            h, w = img_tensor.shape[1:]
            bpp = size_bytes * 8 / (h * w)
            bpp_list.append(bpp)

        break  # Just one batch for speed

    jpeg_results.append({
        'quality': q,
        'bpp': np.mean(bpp_list),
        'psnr': np.mean(psnr_list),
        'ssim': np.mean(ssim_list)
    })

# Parse results
jpeg_bpp = [r['bpp'] for r in jpeg_results]
jpeg_psnr = [r['psnr'] for r in jpeg_results]
jpeg_ssim = [r['ssim'] for r in jpeg_results]
jpeg_labels = [f'JPEG Q={r["quality"]}' for r in jpeg_results]

# Log data to wandb
for i in range(len(ae_bpp)):
    items = {
        "BPP (AE)": ae_bpp[i],
        "PSNR (AE)": ae_psnr[i],
        "SSIM (AE)": ae_ssim[i],
        "Quant Level (AE)": ae_labels[i],
    }
    if i < len(jpeg_bpp):
        items.update({
            "BPP (JPEG)": jpeg_bpp[i],
            "PSNR (JPEG)": jpeg_psnr[i],
            "SSIM (JPEG)": jpeg_ssim[i],
            "JPEG Quality": jpeg_labels[i],
        })
    items["Step"] = i
    wandb.log(items, step=i)

#  Plotting
fig, axs = plt.subplots(2, 1, figsize=(8, 11), sharex=True)

# PSNR vs BPP
axs[0].plot(ae_bpp, ae_psnr, '-o', label="AE", color='royalblue')
axs[0].plot(jpeg_bpp, jpeg_psnr, '-s', label="JPEG", color='darkorange')

for i, t in enumerate(ae_labels):
    axs[0].annotate(f"Q={t}", (ae_bpp[i], ae_psnr[i]),
                    textcoords="offset points", xytext=(0, 6),
                    ha='center', fontsize=8, color='royalblue')

for i, t in enumerate(jpeg_labels):
    axs[0].annotate(t, (jpeg_bpp[i], jpeg_psnr[i]),
                    textcoords="offset points", xytext=(6, -10),
                    ha='left', fontsize=8, color='darkorange')

axs[0].set_ylabel("PSNR (dB)")
axs[0].legend()
axs[0].grid(True)
axs[0].set_title("PSNR vs BPP")

#  SSIM vs BPP
axs[1].plot(ae_bpp, ae_ssim, '-o', label="AE", color='royalblue')
axs[1].plot(jpeg_bpp, jpeg_ssim, '-s', label="JPEG", color='darkorange')

for i, t in enumerate(ae_labels):
    axs[1].annotate(f"Q={t}", (ae_bpp[i], ae_ssim[i]),
                    textcoords="offset points", xytext=(0, 6),
                    ha='center', fontsize=8, color='royalblue')

for i, t in enumerate(jpeg_labels):
    axs[1].annotate(t, (jpeg_bpp[i], jpeg_ssim[i]),
                    textcoords="offset points", xytext=(6, -10),
                    ha='left', fontsize=8, color='darkorange')

axs[1].set_xlabel("Bits Per Pixel (BPP)")
axs[1].set_ylabel("SSIM")
axs[1].legend()
axs[1].grid(True)
axs[1].set_title("SSIM vs BPP")

plt.tight_layout()
plt.savefig("rd_curve_ae_vs_jpeg_with_ssim.png")
wandb.log({"RD Curves": wandb.Image("rd_curve_ae_vs_jpeg_with_ssim.png")})

# Visual comparison image
imgs, _ = next(iter(testloader))
pil_orig = T.ToPILImage()(imgs[0] * 0.5 + 0.5)

with io.BytesIO() as buf:
    pil_orig.save(buf, format='JPEG', quality=50)
    buf.seek(0)
    pil_jpeg50 = Image.open(buf).convert("RGB")

wandb.log({
    "Original": wandb.Image(pil_orig, caption="Original"),
    "JPEG Q=50": wandb.Image(pil_jpeg50, caption="JPEG Q=50")
})

wandb.finish()
# Out:
# Finishing previous runs because reinit is set to 'default'.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>
media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250731_232710-o74lixoh/logs</code>
# Tracking run with wandb version 0.21.0
# Run data is saved locally in <code>/content/wandb/run-20250731_233042-ywh0jcoe</code>
# Syncing run <strong><a href='https://wandb.ai/absoluteking86-sarala-birla-university/latent-compression-vs-jpeg/runs/ywh0jcoe' target="_blank">AE vs JPEG - Rate Distortion with SSIM</a></strong> to <a href='https://wandb.ai/absoluteking86-sarala-birla-university/latent-compression-vs-jpeg' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/absoluteking86-sarala-birla-university/latent-compression-vs-jpeg' target="_blank">https://wandb.ai/absoluteking86-sarala-birla-university/latent-compression-vs-jpeg</a>
#  View run at <a href='https://wandb.ai/absoluteking86-sarala-birla-university/latent-compression-vs-jpeg/runs/ywh0jcoe' target="_blank">https://wandb.ai/absoluteking86-sarala-birla-university/latent-compression-vs-jpeg/runs/ywh0jcoe</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>BPP (AE)</td><td>█▁▁</td></tr><tr><td>BPP (JPEG)</td><td>▁▅█</td></tr><tr><td>PSNR (AE)</td><td>▁▁█</td></tr><tr><td>PSNR (JPEG)</td><td>▁▆█</td></tr><tr><td>Quant Level (AE)</td><td>▁▃█</td></tr><tr><td>SSIM (AE)</td><td>▁▁█</td></tr><tr><td>SSIM (JPEG)</td><td>▁▆█</td></tr><tr><td>Step</td><td>▁▅█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>BPP (AE)</td><td>0.13722</td></tr><tr><td>BPP (JPEG)</td><td>1.77702</td></tr><tr><td>JPEG Quality</td><td>JPEG Q=50</td></tr><tr><td>PSNR (AE)</td><td>25.02033</td></tr><tr><td>PSNR (JPEG)</td><td>28.74508</td></tr><tr><td>Quant Level (AE)</td><td>255</td></tr><tr><td>SSIM (AE)</td><td>0.89684</td></tr><tr><td>SSIM (JPEG)</td><td>0.8833</td></tr><tr><td>Step</td><td>2</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">AE vs JPEG - Rate Distortion with SSIM</strong> at: <a href='https://wandb.ai/absoluteking86-sarala-birla-university/latent-compression-vs-jpeg/runs/ywh0jcoe' target="_blank">https://wandb.ai/absoluteking86-sarala-birla-university/latent-compression-vs-jpeg/runs/ywh0jcoe</a><br> View project at: <a href='https://wandb.ai/absoluteking86-sarala-birla-university/latent-compression-vs-jpeg' target="_blank">https://wandb.ai/absoluteking86-sarala-birla-university/latent-compression-vs-jpeg</a><br>Synced 5 W&B file(s), 3 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250731_233042-ywh0jcoe/logs</code>

# %%
import shutil
from google.colab import files

# Zip the folder
shutil.make_archive("output_images", 'zip', "output_images")

# Download the zip file
files.download("output_images.zip")

# %%
# !pip install comet_ml

from comet_ml import Experiment
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib

experiment = Experiment(
    api_key="cpKLHyfCxG8DOWQEFBNCkAMk7",
    project_name="compression",
    workspace="abhiraj-aryan"
)
# Out:
# Collecting comet_ml
#   Downloading comet_ml-3.50.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting dulwich!=0.20.33,>=0.20.6 (from comet_ml)
#   Downloading dulwich-0.23.2-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (5.2 kB)
# Collecting everett<3.2.0,>=1.0.1 (from everett[ini]<3.2.0,>=1.0.1->comet_ml)
#   Downloading everett-3.1.0-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: jsonschema!=3.1.0,>=2.6.0 in /usr/local/lib/python3.11/dist-packages (from comet_ml) (4.25.0)
# Requirement already satisfied: psutil>=5.6.3 in /usr/local/lib/python3.11/dist-packages (from comet_ml) (5.9.5)
# Collecting python-box<7.0.0 (from comet_ml)
#   Downloading python_box-6.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.8 kB)
# Requirement already satisfied: requests-toolbelt>=0.8.0 in /usr/local/lib/python3.11/dist-packages (from comet_ml) (1.0.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.11/dist-packages (from comet_ml) (2.32.3)
# Requirement already satisfied: rich>=13.3.2 in /usr/local/lib/python3.11/dist-packages (from comet_ml) (13.9.4)
# Requirement already satisfied: semantic-version>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from comet_ml) (2.10.0)
# Requirement already satisfied: sentry-sdk>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from comet_ml) (2.34.0)
# Requirement already satisfied: simplejson in /usr/local/lib/python3.11/dist-packages (from comet_ml) (3.20.1)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from comet_ml) (2.5.0)
# Requirement already satisfied: wrapt>=1.11.2 in /usr/local/lib/python3.11/dist-packages (from comet_ml) (1.17.2)
# Requirement already satisfied: wurlitzer>=1.0.2 in /usr/local/lib/python3.11/dist-packages (from comet_ml) (3.1.1)
# Collecting configobj (from everett[ini]<3.2.0,>=1.0.1->comet_ml)
#   Downloading configobj-5.0.9-py2.py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (0.26.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.18.4->comet_ml) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.18.4->comet_ml) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.18.4->comet_ml) (2025.7.14)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13.3.2->comet_ml) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13.3.2->comet_ml) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=13.3.2->comet_ml) (0.1.2)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from referencing>=0.28.4->jsonschema!=3.1.0,>=2.6.0->comet_ml) (4.14.1)
# Downloading comet_ml-3.50.0-py3-none-any.whl (729 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 729.6/729.6 kB 14.8 MB/s eta 0:00:00
# Downloading dulwich-0.23.2-cp311-cp311-manylinux_2_28_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 39.6 MB/s eta 0:00:00
# Downloading everett-3.1.0-py2.py3-none-any.whl (35 kB)
# Downloading python_box-6.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 48.7 MB/s eta 0:00:00
# Downloading configobj-5.0.9-py2.py3-none-any.whl (35 kB)
# Installing collected packages: everett, python-box, dulwich, configobj, comet_ml
#   Attempting uninstall: python-box
#     Found existing installation: python-box 7.3.2
#     Uninstalling python-box-7.3.2:
#       Successfully uninstalled python-box-7.3.2
# Successfully installed comet_ml-3.50.0 configobj-5.0.9 dulwich-0.23.2 everett-3.1.0 python-box-6.1.0
# COMET WARNING: To get all data logged automatically, import comet_ml before the following modules: torch.
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/abhiraj-aryan/compression/875e3b52f89446989932d2b42bfcc5b2

# %%
# # ============================
# # Final Block for Comet Logging + Publication Quality Graphs
# # ============================

# from comet_ml import start
# from comet_ml.integration.pytorch import log_model
# import matplotlib.pyplot as plt
# import seaborn as sns
# import matplotlib

# # ---------- Start Comet ----------
# experiment = start(
#     api_key="cpKLHyfCxG8DOWQEFBNCkAMk7",
#     project_name="compression",
#     workspace="abhiraj-aryan"
# )

# # ---------- Publication Style ----------
# sns.set(style="whitegrid", font_scale=1.2)
# matplotlib.rcParams['pdf.fonttype'] = 42
# matplotlib.rcParams['ps.fonttype'] = 42

# # ---------- PSNR vs BPP (Publication Quality) ----------
# plt.figure(figsize=(9, 6))
# plt.plot(ae_bpp, ae_psnr, '-o', label="LC-Net (AE-based)", color='steelblue', linewidth=2.5, markersize=7)
# plt.plot(jpeg_bpp, jpeg_psnr, '-s', label="JPEG", color='darkorange', linewidth=2.5, markersize=6)

# for i, txt in enumerate(ae_labels):
#     plt.annotate(f"Q={txt}", (ae_bpp[i]+0.02, ae_psnr[i]+0.2), fontsize=9, color='steelblue')
# for i, txt in enumerate(jpeg_labels):
#     plt.annotate(txt, (jpeg_bpp[i]+0.05, jpeg_psnr[i]+0.15), fontsize=9, color='darkorange')

# plt.xlabel("Bits Per Pixel (BPP)", fontsize=13)
# plt.ylabel("PSNR (dB)", fontsize=13)
# plt.title("Rate–Distortion Curve: LC-Net vs JPEG", fontsize=14)
# plt.grid(True, linestyle='--', alpha=0.6)
# plt.legend(loc="lower right", fontsize=11)
# plt.tight_layout()

# # Save and log to Comet
# plt.savefig("rd_curve_ae_vs_jpeg_comet.svg", format='svg')
# experiment.log_figure(figure_name="RD_Curve_PSNR_BPP", figure=plt)
# plt.close()

# # ---------- SSIM vs BPP ----------
# plt.figure(figsize=(9, 6))
# plt.plot(ae_bpp, ae_ssim, '-o', label="LC-Net (AE-based)", color='royalblue', linewidth=2.5, markersize=7)
# plt.plot(jpeg_bpp, jpeg_ssim, '-s', label="JPEG", color='darkorange', linewidth=2.5, markersize=6)

# for i, txt in enumerate(ae_labels):
#     plt.annotate(f"Q={txt}", (ae_bpp[i]+0.02, ae_ssim[i]+0.01), fontsize=9, color='royalblue')
# for i, txt in enumerate(jpeg_labels):
#     plt.annotate(txt, (jpeg_bpp[i]+0.05, jpeg_ssim[i]+0.01), fontsize=9, color='darkorange')

# plt.xlabel("Bits Per Pixel (BPP)", fontsize=13)
# plt.ylabel("SSIM", fontsize=13)
# plt.title("Rate–Distortion Curve (SSIM): LC-Net vs JPEG", fontsize=14)
# plt.grid(True, linestyle='--', alpha=0.6)
# plt.legend(loc="lower right", fontsize=11)
# plt.tight_layout()

# # Save and log to Comet
# plt.savefig("rd_curve_ssim_comet.svg", format='svg')
# experiment.log_figure(figure_name="RD_Curve_SSIM_BPP", figure=plt)
# plt.close()

# # ---------- Visual Comparison Images ----------
# # Make images bigger (e.g., 1024x1024) and log
# from PIL import Image
# import torchvision.transforms as T
# import io
# import numpy as np

# imgs, _ = next(iter(testloader))
# pil_orig = T.ToPILImage()(imgs[0] * 0.5 + 0.5)
# pil_orig = pil_orig.resize((1024, 1024), Image.BICUBIC)

# # JPEG quality 50 image
# with io.BytesIO() as buf:
#     pil_orig.save(buf, format='JPEG', quality=50)
#     buf.seek(0)
#     pil_jpeg50 = Image.open(buf).convert("RGB").resize((1024, 1024), Image.BICUBIC)

# # Save and log images
# pil_orig.save("original_big.png")
# pil_jpeg50.save("jpeg_q50_big.png")
# experiment.log_image("original_big.png", name="Original_HighRes")
# experiment.log_image("jpeg_q50_big.png", name="JPEG_Q50_HighRes")

# print("✅ Publication-quality graphs and images saved & logged to Comet.")
# Out:
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.

# %%
# import wandb
# import torch
# import torch.nn.functional as F
# from PIL import Image
# import torchvision.transforms as T
# import io
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
# import matplotlib
# from skimage.metrics import structural_similarity as sk_ssim

# # ---------- Init wandb ----------
# wandb.init(
#     project="latent-compression-vs-jpeg",
#     name="AE vs JPEG - High Quality Graphs",
#     config={
#         "model": "AE latent compression",
#         "baseline": "JPEG",
#         "dataset": "CIFAR-10"
#     }
# )

# # ---------- Publication Style ----------
# sns.set(style="whitegrid", font_scale=1.4)
# matplotlib.rcParams['pdf.fonttype'] = 42
# matplotlib.rcParams['ps.fonttype'] = 42

# # ---------- AE Metrics ----------
# ae_bpp = summary['BPP_mean'].tolist()
# ae_psnr = summary['PSNR_Compressed_mean'].tolist()
# ae_ssim = summary['SSIM_mean'].tolist()
# ae_labels = summary['quant_level'].tolist()

# # ---------- JPEG Evaluation ----------
# jpeg_results = []
# jpeg_qualities = [10, 30, 50, 70, 90]

# for q in jpeg_qualities:
#     bpp_list, psnr_list, ssim_list = [], [], []
#     for imgs, _ in testloader:
#         imgs = imgs.cpu()
#         for img in imgs:
#             pil = T.ToPILImage()(img * 0.5 + 0.5)
#             with io.BytesIO() as buf:
#                 pil.save(buf, format='JPEG', quality=q)
#                 jpeg_bytes = buf.getvalue()

#             size_bytes = len(jpeg_bytes)
#             pil_jpeg = Image.open(io.BytesIO(jpeg_bytes)).convert("RGB")
#             img_jpeg = T.ToTensor()(pil_jpeg).clamp(0, 1)
#             img_tensor = T.ToTensor()(pil).clamp(0, 1)

#             # PSNR
#             mse = F.mse_loss(img_jpeg, img_tensor)
#             psnr = float('inf') if mse == 0 else 20 * torch.log10(torch.tensor(1.0)) - 10 * torch.log10(mse)
#             psnr_list.append(psnr.item())

#             # SSIM
#             orig_np = img_tensor.permute(1, 2, 0).numpy()
#             jpeg_np = img_jpeg.permute(1, 2, 0).numpy()
#             ssim_val = np.mean([
#                 sk_ssim(orig_np[:, :, c], jpeg_np[:, :, c], data_range=1.0)
#                 for c in range(3)
#             ])
#             ssim_list.append(ssim_val)

#             # BPP
#             h, w = img_tensor.shape[1:]
#             bpp = size_bytes * 8 / (h * w)
#             bpp_list.append(bpp)
#         break  # Only one batch for speed

#     jpeg_results.append({
#         'quality': q,
#         'bpp': np.mean(bpp_list),
#         'psnr': np.mean(psnr_list),
#         'ssim': np.mean(ssim_list)
#     })

# jpeg_bpp = [r['bpp'] for r in jpeg_results]
# jpeg_psnr = [r['psnr'] for r in jpeg_results]
# jpeg_ssim = [r['ssim'] for r in jpeg_results]
# jpeg_labels = [f'JPEG Q={r["quality"]}' for r in jpeg_results]

# # ---------- Log Data to wandb ----------
# for i in range(len(ae_bpp)):
#     items = {
#         "BPP (AE)": ae_bpp[i],
#         "PSNR (AE)": ae_psnr[i],
#         "SSIM (AE)": ae_ssim[i],
#         "Quant Level (AE)": ae_labels[i],
#     }
#     if i < len(jpeg_bpp):
#         items.update({
#             "BPP (JPEG)": jpeg_bpp[i],
#             "PSNR (JPEG)": jpeg_psnr[i],
#             "SSIM (JPEG)": jpeg_ssim[i],
#             "JPEG Quality": jpeg_labels[i],
#         })
#     items["Step"] = i
#     wandb.log(items, step=i)

# # ---------- Graphs: Publication Quality ----------
# fig, axs = plt.subplots(2, 1, figsize=(9, 12), sharex=True)

# # PSNR vs BPP
# axs[0].plot(ae_bpp, ae_psnr, '-o', label="AE (LC-Net)", color='royalblue', linewidth=2.5, markersize=7)
# axs[0].plot(jpeg_bpp, jpeg_psnr, '-s', label="JPEG", color='darkorange', linewidth=2.5, markersize=6)

# for i, t in enumerate(ae_labels):
#     axs[0].annotate(f"Q={t}", (ae_bpp[i]+0.02, ae_psnr[i]+0.2), fontsize=10, color='royalblue')
# for i, t in enumerate(jpeg_labels):
#     axs[0].annotate(t, (jpeg_bpp[i]+0.05, jpeg_psnr[i]+0.15), fontsize=10, color='darkorange')

# axs[0].set_ylabel("PSNR (dB)")
# axs[0].legend(fontsize=11)
# axs[0].grid(True, linestyle='--', alpha=0.6)
# axs[0].set_title("PSNR vs BPP")

# # SSIM vs BPP
# axs[1].plot(ae_bpp, ae_ssim, '-o', label="AE (LC-Net)", color='royalblue', linewidth=2.5, markersize=7)
# axs[1].plot(jpeg_bpp, jpeg_ssim, '-s', label="JPEG", color='darkorange', linewidth=2.5, markersize=6)

# for i, t in enumerate(ae_labels):
#     axs[1].annotate(f"Q={t}", (ae_bpp[i]+0.02, ae_ssim[i]+0.01), fontsize=10, color='royalblue')
# for i, t in enumerate(jpeg_labels):
#     axs[1].annotate(t, (jpeg_bpp[i]+0.05, jpeg_ssim[i]+0.01), fontsize=10, color='darkorange')

# axs[1].set_xlabel("Bits Per Pixel (BPP)")
# axs[1].set_ylabel("SSIM")
# axs[1].legend(fontsize=11)
# axs[1].grid(True, linestyle='--', alpha=0.6)
# axs[1].set_title("SSIM vs BPP")

# plt.tight_layout()
# plt.savefig("rd_curve_ae_vs_jpeg_pubquality.png", dpi=300)
# wandb.log({"RD Curves": wandb.Image("rd_curve_ae_vs_jpeg_pubquality.png")})

# # ---------- Visual Comparison (High Res Side-by-Side) ----------
# imgs, _ = next(iter(testloader))
# pil_orig = T.ToPILImage()(imgs[0] * 0.5 + 0.5).resize((1024, 1024), Image.BICUBIC)

# with io.BytesIO() as buf:
#     pil_orig.save(buf, format='JPEG', quality=50)
#     buf.seek(0)
#     pil_jpeg50 = Image.open(buf).convert("RGB").resize((1024, 1024), Image.BICUBIC)

# # Combine in one figure
# fig, ax = plt.subplots(1, 2, figsize=(12, 6))
# ax[0].imshow(pil_orig)
# ax[0].set_title("Original", fontsize=13)
# ax[0].axis('off')

# ax[1].imshow(pil_jpeg50)
# ax[1].set_title("JPEG Q=50", fontsize=13)
# ax[1].axis('off')

# plt.tight_layout()
# plt.savefig("visual_comparison_pubquality.png", dpi=300)
# wandb.log({"Comparison Images": wandb.Image("visual_comparison_pubquality.png")})

# wandb.finish()

# %% [markdown]
# **Rate-Distortion Curves & Compression Time (Figures 1–3)**

# %%
df = pd.DataFrame(results)

# Figure 1: PSNR vs BPP
plt.figure(figsize=(7,5))
plt.plot(df["BPP"], df["PSNR_Compressed"], '-o', color='royalblue')
plt.xlabel("Bits Per Pixel (BPP)")
plt.ylabel("PSNR (dB)")
plt.title("Rate-Distortion Curve (PSNR vs BPP)")
plt.grid(True)
plt.tight_layout()
plt.savefig("fig1_psnr_vs_bpp.png")
wandb.log({"Figure 1 - PSNR vs BPP": wandb.Image("fig1_psnr_vs_bpp.png")})

# Figure 2: SSIM vs BPP
plt.figure(figsize=(7,5))
plt.plot(df["BPP"], df["SSIM"], '-o', color='darkgreen')
plt.xlabel("Bits Per Pixel (BPP)")
plt.ylabel("SSIM")
plt.title("Rate-Distortion Curve (SSIM vs BPP)")
plt.grid(True)
plt.tight_layout()
plt.savefig("fig2_ssim_vs_bpp.png")
wandb.log({"Figure 2 - SSIM vs BPP": wandb.Image("fig2_ssim_vs_bpp.png")})

# Figure 3: Compression Time vs BPP
plt.figure(figsize=(7,5))
plt.plot(df["BPP"], df["Compression_Time_ms"], '-o', color='darkorange')
plt.xlabel("Bits Per Pixel (BPP)")
plt.ylabel("Compression Time (ms)")
plt.title("Compression Time vs BPP")
plt.grid(True)
plt.tight_layout()
plt.savefig("fig3_time_vs_bpp.png")
wandb.log({"Figure 3 - Compression Time vs BPP": wandb.Image("fig3_time_vs_bpp.png")})
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# /tmp/ipython-input-3557461755.py in <cell line: 0>()
#      10 plt.tight_layout()
#      11 plt.savefig("fig1_psnr_vs_bpp.png")
# ---> 12 wandb.log({"Figure 1 - PSNR vs BPP": wandb.Image("fig1_psnr_vs_bpp.png")})
#      13
#      14 # Figure 2: SSIM vs BPP
#
# /usr/local/lib/python3.11/dist-packages/wandb/sdk/lib/preinit.py in preinit_wrapper(*args, **kwargs)
#      34 ) -> Callable:
#      35     def preinit_wrapper(*args: Any, **kwargs: Any) -> Any:
# ---> 36         raise wandb.Error(f"You must call wandb.init() before {name}()")
#      37
#      38     preinit_wrapper.__name__ = str(name)
#
# Error: You must call wandb.init() before wandb.log()

# %% [markdown]
# **PSNR vs BPP & SSIM vs BPP (Figures 7 & 8)**

# %%
# (Keep your JPEG evaluation loop as it is)

fig, ax = plt.subplots(figsize=(7,5))
ax.plot(ae_bpp, ae_psnr, '-o', label="AE", color='royalblue')
ax.plot(jpeg_bpp, jpeg_psnr, '-s', label="JPEG", color='darkorange')
ax.set_xlabel("Bits Per Pixel (BPP)")
ax.set_ylabel("PSNR (dB)")
ax.legend()
ax.set_title("PSNR vs BPP")
plt.grid(True)
plt.tight_layout()
plt.savefig("fig8_psnr_vs_bpp.png")
wandb.log({"Figure 8 - PSNR vs BPP (AE vs JPEG)": wandb.Image("fig8_psnr_vs_bpp.png")})

fig, ax = plt.subplots(figsize=(7,5))
ax.plot(ae_bpp, ae_ssim, '-o', label="AE", color='royalblue')
ax.plot(jpeg_bpp, jpeg_ssim, '-s', label="JPEG", color='darkorange')
ax.set_xlabel("Bits Per Pixel (BPP)")
ax.set_ylabel("SSIM")
ax.legend()
ax.set_title("SSIM vs BPP")
plt.grid(True)
plt.tight_layout()
plt.savefig("fig7_ssim_vs_bpp.png")
wandb.log({"Figure 7 - SSIM vs BPP (AE vs JPEG)": wandb.Image("fig7_ssim_vs_bpp.png")})
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# /tmp/ipython-input-2054814972.py in <cell line: 0>()
#      11 plt.tight_layout()
#      12 plt.savefig("fig8_psnr_vs_bpp.png")
# ---> 13 wandb.log({"Figure 8 - PSNR vs BPP (AE vs JPEG)": wandb.Image("fig8_psnr_vs_bpp.png")})
#      14
#      15 fig, ax = plt.subplots(figsize=(7,5))
#
# /usr/local/lib/python3.11/dist-packages/wandb/sdk/lib/preinit.py in preinit_wrapper(*args, **kwargs)
#      34 ) -> Callable:
#      35     def preinit_wrapper(*args: Any, **kwargs: Any) -> Any:
# ---> 36         raise wandb.Error(f"You must call wandb.init() before {name}()")
#      37
#      38     preinit_wrapper.__name__ = str(name)
#
# Error: You must call wandb.init() before wandb.log()

# %% [markdown]
# **BPP and Compression Ratio vs Quantization Level (Figure 5)**

# %%
fig, ax1 = plt.subplots(figsize=(7,5))

color1 = 'royalblue'
ax1.set_xlabel('Quantization Level')
ax1.set_ylabel('BPP', color=color1)
ax1.plot(summary['quant_level'], summary['BPP_mean'], color=color1, marker='o', label='BPP')
ax1.tick_params(axis='y', labelcolor=color1)

ax2 = ax1.twinx()
color2 = 'darkorange'
ax2.set_ylabel('Compression Ratio', color=color2)
ax2.plot(summary['quant_level'], summary['Compression_Ratio_mean'], color=color2, marker='s', label='Compression Ratio')
ax2.tick_params(axis='y', labelcolor=color2)

plt.title("BPP and Compression Ratio vs Quantization Level")
fig.tight_layout()

fig.savefig("fig5_bpp_cr_vs_quant.png")
wandb.log({"Figure 5 - BPP & Compression Ratio": wandb.Image("fig5_bpp_cr_vs_quant.png")})
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# /tmp/ipython-input-3138869269.py in <cell line: 0>()
#      17
#      18 fig.savefig("fig5_bpp_cr_vs_quant.png")
# ---> 19 wandb.log({"Figure 5 - BPP & Compression Ratio": wandb.Image("fig5_bpp_cr_vs_quant.png")})
#
# /usr/local/lib/python3.11/dist-packages/wandb/sdk/lib/preinit.py in preinit_wrapper(*args, **kwargs)
#      34 ) -> Callable:
#      35     def preinit_wrapper(*args: Any, **kwargs: Any) -> Any:
# ---> 36         raise wandb.Error(f"You must call wandb.init() before {name}()")
#      37
#      38     preinit_wrapper.__name__ = str(name)
#
# Error: You must call wandb.init() before wandb.log()

# %% [markdown]
# **PSNR vs Quantization Level (Figure 6)**

# %%
fig, ax = plt.subplots(figsize=(7,5))
ax.errorbar(summary['quant_level'], summary['PSNR_Compressed_mean'],
            yerr=summary['PSNR_Compressed_std'], label='PSNR', marker='o', color='royalblue')

ax.set_xlabel('Quantization Level')
ax.set_ylabel('PSNR (dB)')
ax.set_title('PSNR vs Quantization Level')
ax.legend()
plt.tight_layout()

fig.savefig("fig6_psnr_vs_quant.png")
wandb.log({"Figure 6 - PSNR vs Quant Level": wandb.Image("fig6_psnr_vs_quant.png")})

# %% [markdown]
# **Figure 4 (High-Res Visual Comparisons)**

# %%
import torchvision.utils as vutils
import os

os.makedirs("output_images/best_samples", exist_ok=True)

GRID_SIZE = 400  # for paper
quant_levels = [64, 127, 255]

def is_good_image(img, brightness_low=0.2, brightness_high=0.8):
    """Filter: image brightness must be within a good range."""
    mean_val = img.mean().item()
    return brightness_low < mean_val < brightness_high

# 1️⃣ Select good images from test set
good_imgs = []
for imgs, _ in testloader:
    for img in imgs:
        if is_good_image(img):
            good_imgs.append(img)
    if len(good_imgs) >= 8:  # we only need 8 nice ones
        break

good_imgs = torch.stack(good_imgs[:8]).to(device)
print(f"✅ Selected {good_imgs.size(0)} high-quality images!")

# 2️⃣ Create grids for each quantization level
for quant in quant_levels:
    with torch.no_grad():
        e1 = autoencoder.enc1(good_imgs)
        e2 = autoencoder.enc2(e1)
        e3 = autoencoder.enc3(e2)
        z = latent_compressor.encoder(e3)
        z_quant = quantize(z)

        # AE recon
        decoded_e3_ae = latent_compressor.decoder(z_quant)
        d1_ae = autoencoder.dec1(decoded_e3_ae)
        d2_ae = autoencoder.dec2(torch.cat([d1_ae, e2], dim=1))
        recon_ae = autoencoder.dec3(torch.cat([d2_ae, e1], dim=1))

        # Compressed recon
        z_int = torch.clamp(torch.round(z_quant * quant), -quant, quant).to(torch.int8)
        z_np = z_int.cpu().numpy()
        z_np_decomp = np.frombuffer(zlib.decompress(zlib.compress(z_np.tobytes(), level=9)), dtype=np.int8)
        z_t_decomp = torch.from_numpy(z_np_decomp.copy()).float() / quant
        z_t_decomp = z_t_decomp.view_as(z).to(device)

        decoded_e3 = latent_compressor.decoder(z_t_decomp)
        d1 = autoencoder.dec1(decoded_e3)
        d2 = autoencoder.dec2(torch.cat([d1, e2], dim=1))
        recon = autoencoder.dec3(torch.cat([d2, e1], dim=1))

    originals = good_imgs.cpu().clamp(0, 1)
    recon_ae = recon_ae.cpu().clamp(0, 1)
    recon = recon.cpu().clamp(0, 1)

    grid = vutils.make_grid(
        torch.cat([originals, recon_ae, recon], dim=0),
        nrow=originals.size(0),
        padding=4,
        pad_value=1
    )

    fig_path = f"output_images/best_samples/figure4_best_q{quant}.png"
    plt.figure(figsize=(GRID_SIZE/100, GRID_SIZE/300 * 3))
    plt.imshow(grid.permute(1, 2, 0).numpy())
    plt.axis('off')
    plt.savefig(fig_path, bbox_inches='tight', pad_inches=0, dpi=300)
    plt.close()

    print(f"✅ Saved better sample: {fig_path}")
# Out:
# ✅ Selected 8 high-quality images!
# ✅ Saved better sample: output_images/best_samples/figure4_best_q64.png
# ✅ Saved better sample: output_images/best_samples/figure4_best_q127.png
# ✅ Saved better sample: output_images/best_samples/figure4_best_q255.png

# %%
import torch
from torchvision.utils import save_image, make_grid
import os

# Create directory for saving grids
os.makedirs("comparison_grids", exist_ok=True)

autoencoder.eval()

num_grids = 5         # Number of grids to save
images_per_grid = 3   # Number of image pairs per grid
idx = 0

with torch.no_grad():
    for i, (imgs, _) in enumerate(testloader):
        imgs = imgs.to(device)
        recon, _ = autoencoder(imgs)

        # Only take a small subset for each grid
        for g in range(num_grids):
            start = g * images_per_grid
            end = start + images_per_grid

            if end > imgs.size(0):
                break

            originals = imgs[start:end]
            reconstructions = recon[start:end]

            # Combine original and reconstructed in one grid:
            # First row = originals, Second row = reconstructions
            grid = torch.cat([originals, reconstructions], dim=0)

            # Make grid (2 rows, images_per_grid columns)
            grid_img = make_grid(grid, nrow=images_per_grid, normalize=True, scale_each=True)

            # Save the grid
            save_path = f"comparison_grids/grid_{g+1}.png"
            save_image(grid_img, save_path)
            print(f"Saved: {save_path}")

        # Only create 4-5 grids, break after enough images
        break
# Out:
# Saved: comparison_grids/grid_1.png
# Saved: comparison_grids/grid_2.png
# Saved: comparison_grids/grid_3.png
# Saved: comparison_grids/grid_4.png
# Saved: comparison_grids/grid_5.png

# %%
import torch
from torchvision.utils import save_image, make_grid
import os

# Ensure models are in eval mode
autoencoder.eval()
latent_compressor.eval()

os.makedirs("comparison_grids", exist_ok=True)

# Number of grids you want
num_grids = 5
images_per_grid = 4  # number of images in each grid

with torch.no_grad():
    data_iter = iter(testloader)

    for grid_idx in range(num_grids):
        try:
            imgs, _ = next(data_iter)
        except StopIteration:
            data_iter = iter(testloader)
            imgs, _ = next(data_iter)

        imgs = imgs.to(device)[:images_per_grid]  # Take only required number

        # Autoencoder reconstruction (no compression)
        ae_recon, _ = autoencoder(imgs)

        # Compressed reconstruction using latent compressor
        e1 = autoencoder.enc1(imgs)
        e2 = autoencoder.enc2(e1)
        e3 = autoencoder.enc3(e2)

        z = latent_compressor.encoder(e3)
        decoded_e3 = latent_compressor.decoder(z)

        d1 = autoencoder.dec1(decoded_e3)
        d1_cat = torch.cat([d1, e2], 1)
        d2 = autoencoder.dec2(d1_cat)
        d2_cat = torch.cat([d2, e1], 1)
        comp_recon = autoencoder.dec3(d2_cat)

        # Stack: Original, AE, Compressed for each image
        all_images = []
        for i in range(images_per_grid):
            all_images.append(imgs[i])
            all_images.append(ae_recon[i])
            all_images.append(comp_recon[i])

        grid = make_grid(all_images, nrow=3, normalize=True, scale_each=True)

        save_path = f"comparison_grids/grid_{grid_idx+1}.png"
        save_image(grid, save_path)
        print(f"Saved {save_path}")
# Out:
# Saved comparison_grids/grid_1.png
# Saved comparison_grids/grid_2.png
# Saved comparison_grids/grid_3.png
# Saved comparison_grids/grid_4.png
# Saved comparison_grids/grid_5.png

# %%
import torch
import matplotlib.pyplot as plt
from torchvision.utils import make_grid

# Ensure models are in eval mode
autoencoder.eval()
latent_compressor.eval()

# Get a few test samples
imgs, _ = next(iter(testloader))
imgs = imgs[:3].to(device)  # pick 3 images

with torch.no_grad():
    # Autoencoder reconstructions
    recon_ae, e3 = autoencoder(imgs)

    # Latent compressor reconstructions
    z = latent_compressor.encoder(e3)
    decoded_e3 = latent_compressor.decoder(z)
    d1 = autoencoder.dec1(decoded_e3)
    d1_cat = torch.cat([d1, autoencoder.enc2(autoencoder.enc1(imgs))], 1)
    d2 = autoencoder.dec2(d1_cat)
    d2_cat = torch.cat([d2, autoencoder.enc1(imgs)], 1)
    recon_compressed = autoencoder.dec3(d2_cat)

# Create grid: Original, AE recon, Compressed recon for each sample
images_to_show = []
for i in range(imgs.size(0)):
    images_to_show.append(imgs[i].cpu())
    images_to_show.append(recon_ae[i].cpu())
    images_to_show.append(recon_compressed[i].cpu())

# Denormalize images from [-1,1] to [0,1]
images_to_show = [(img * 0.5 + 0.5).clamp(0,1) for img in images_to_show]

# Create grid (3 rows = samples, 3 columns = variants)
grid = make_grid(images_to_show, nrow=3, padding=10)

# Save and show
plt.figure(figsize=(12, 12))
plt.imshow(grid.permute(1, 2, 0))
plt.axis('off')
plt.title("Original | Autoencoder Recon | Latent Compressor Recon")
plt.savefig("output_images/comparison_grid.png", bbox_inches='tight')
plt.show()

print("Saved grid to output_images/comparison_grid.png")
# Out:
# Saved grid to output_images/comparison_grid.png
